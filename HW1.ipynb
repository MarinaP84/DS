# %%
# Словари (ассоциативные массивы):
person = {"имя": "Марина", "возраст": 20, "курс": "3", "предметы": "теория вероятности, английский язык, статистика, философия"}
name = person["предметы"]
name
# Out:
# 'теория вероятности, английский язык, статистика, философия'

# %% [markdown]
# # Новый раздел
