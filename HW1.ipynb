# %%
# Словари (ассоциативные массивы):
person = {"имя": "Марина", "возраст": 20, "курс": "3", "предметы": "теория вероятности, английский язык, статистика, философия, высшая математика"}
name = person["предметы"]
name
# Out:
# 'теория вероятности, английский язык, статистика, философия, высшая математика'

# %% [markdown]
# # Новый раздел
